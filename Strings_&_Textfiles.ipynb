# %% [markdown]
# <a href="https://colab.research.google.com/github/kscott64/intro-to-programming/blob/main/Strings_%26_Textfiles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# subscript operator

# %% [markdown]
# subscript operator

# %%
name = "Alan"
name[0]
name[-1]
# Out:
# 'n'

# %% [markdown]
# Slicing

# %%
name = "myfile.txt"
name[0:] # entirestring
name[0:1]
name[-3:] # last3chars
# Out:
# 'txt'

# %% [markdown]
# substring with In operator

# %%
files = ["file.txt", "file1.txt", "file2.txt"]
for filename in files:
    if ".txt" in filename:
        print(filename)
# Out:
# file.txt
# file1.txt
# file2.txt
