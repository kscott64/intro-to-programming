# %%
data types examples
integer_example= 10
student_name = "Kallen"
boolean_example = False
float_example = 90.2

# %% [markdown]
# input/output example

# %%
student_name = input("Kallen")
print(student_name)
# Out:
# Kallenk\
# k\

# %% [markdown]
# type conversion

# %%
x_int = int(input("entervalue"))
x_float = float(input("entervalue"))
print(x_int)
print(x_float)
# Out:
# entervalue32
# entervalue56
# 32
# 56.0

# %% [markdown]
# Arithmetic example

# %%
x = 4
y = 5
z = x + y
print(z)
# Out:
# 9

# %%
retail_price = 20
discount_number = 5
final_price = retail_price - discount_number
print(final_price)
# Out:
# 15
