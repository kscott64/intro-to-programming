# %%
for eachpass in range(7):
  print("live", end ="")
# Out:
# livelivelivelivelivelivelive

# %%
for count in range(5):
  print(count,end ="")
# Out:
# 01234

# %%
for count in range(1,4):
  print(count)
# Out:
# 1
# 2
# 3

# %%
import math

area = math.pi*8**2
radius = sqrt(area)
print(area)
# Out:
# 78.53981633974483

# %%
n=int(input(""))
if n>90:
  grade='A'
elif n>80:
  grade='B'
elif n>70:
  grade='C'
elif n>60:
  grade='D'
else:
  grade='F'
print(grade)
# Out:
# 54
# F

# %%
sum = 0.0
data = input("")
while data!="":
  number = float(data)
  sum = sum + number
  data = input("")
print("", sum)
